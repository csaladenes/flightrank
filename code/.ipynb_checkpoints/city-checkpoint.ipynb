# %%
import pandas as pd, json, numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
L=json.loads(file('../json/L.json','r').read())
M=json.loads(file('../json/M.json','r').read())
N=json.loads(file('../json/N.json','r').read())

# %%
AP={}
for c in M:
    if c not in AP:AP[c]={}
    for i in range(len(L[c])):
        AP[c][N[c][i]]=L[c][i]

# %%
baseurl='https://www.airportia.com/'
import requests, urllib2

# %%
def urlgetter(url):
    s = requests.Session()
    cookiesopen = s.get(url)
    cookies=str(s.cookies)
    fcookies=[[k[:k.find('=')],k[k.find('=')+1:k.find(' for ')]] for k in cookies[cookies.find('Cookie '):].split('Cookie ')[1:]]
    #push token
    opener = urllib2.build_opener()
    for k in fcookies:
        opener.addheaders.append(('Cookie', k[0]+'='+k[1]))
    #read html
    return s.get(url).content

# %%
SD={}
SC=json.loads(file('../json/SC2.json','r').read())

# %%
for h in range(len(AP.keys())):
    c=AP.keys()[h]
    #country not parsed yet
    if c in SC:
        if c not in SD:
            print h,c
            airportialinks=AP[c]
            #all airports of country, where there is traffic
            for i in airportialinks:
                if i in SC[c]:
                    print i,
                    if i not in sch:sch[i]={}
                    url=baseurl+airportialinks[i]+'/map/'
                    m=urlgetter(url)
                    z=m[m.find('<p class="sub-h1">'):]
                    SD[i]=z[z.find('>')+1:z.find(',')]
            print
# Out:
# 0 Canada
# YUY YUX YUL XBE YUB YUD YRT YUT LAK ZFN YBX YBR YBT YBV YBK YBL YBB YBC YLL YBF YBG ZGR XKS ZGI AKV YIF YIO YIK YIV XTL ZMT YFA YFB YFC YFO YFH YFJ YFS YPR YPQ YPX YPY YPB YPC YPA YPJ YPH YPN YPO YPL YPM ZNA XQU YMT YMX QBC YMM YMO YMN ZAC SUR YSK YSJ YSO YSM YSG XLB YSY YSU YPW YZP YZR YZS YZT YZV YZZ YZD YZF YZG YQR YTZ YTR YTS YTQ YTL YTH YTE YHK YHI YHO YHM YHD YHE YHZ YHY YHR YHP YHU ZRJ YAY YAX YAZ YAU YAT YAM YAH YAG YAA YAC YAB ZEL ZEM KEW KES ZST YWP KIF YWG YWB YWL YWK YWJ ZSJ YWH XGR YLW YLE YLC ZFM YEK YEG YEY YER YEV WNN YKA YKG YKF YKL YKQ YKU ZBF ZBM ZTM YRL YRA YRB YRG YRS YYU YYT YYQ YYR YYY YYZ YYE YYD YYF YYC YYB YYH YYJ MSA YOJ YOH ZKE YOC YOA YOW YVO YDF YDA YDT YDP YDQ YVT YVP YVQ YVR YVZ YVB YVM ZPB CXH YJT XSI YCY YCS YCR YCW YCK YCH YCO YCN YCL YCB YCG YCD YQM YQL YQI YQK YQD YQG YQF YQC YQB YQY YQX YQZ YQU YQT YQW YQQ ZUM YXX YXY YXS YXP YXT YXU YXJ YXH YXN YXL YSB YXC YXE YNM YNO YND YNE YNA YNC YNP YNS YST YGB YGO YGL YGK YGH YGW YGV YGT YGR YGP YGZ YGX
# 1 Turkmenistan
# CRZ ASB KRW TAZ MYP
# 2 Saint Helena
# ASI
# 3 Lithuania
# VNO KUN PLQ
# 4 Cambodia
# PNH REP KOS
# 5 Ethiopia
# AXU DIR AMH SZE LLI MQX ASO AWA GDE GMB JIM JIJ ADD DSE GDQ HUE BJR DEM
# 6 Aruba
# AUA
# 7 Swaziland
#
# 8 Perú
# ATA LIM PEM PCL ILQ CIX AQP JUL TCQ HUU IQT TGI PIU TYL CJA JAU CUZ TPP TRU AYP TBP ANS
# 9 Argentina
# PRA UAQ NQN EQS SFN RHD AEP RGA CRD RGL ROS IGR AFA FTE PSS LUQ COR RES REL CTC PMY MDZ MDQ FMA TUC BRC RCU USH SDE VDM CNQ IRJ EZE SLA BHI RSA JUJ
# 10 Bolivia
# CIJ GYA BYC VVI RIB TJA SRE POI RBQ LPB CBB ORU TDD
# 11 Cameroon
# NGE DLA NSI MVR GOU BFX
# 12 Burkina Faso
# BOY OUA
# 13 Ghana
# ACC TML TKD KMS
# 14 Saudi Arabia
# DWD DMM YNB TIF RAE ELQ SHW RAH AQI HOF EJH MED WAE GIZ EWD ABT JED HAS URY AJF AHB BHH RUH TUU TUI
# 15 Cape Verde
# SNE VXE SFL RAI BVC MMO SID
# 16 United States Minor Outlying Islands
# AWK BAR
# 17 Cocos (Keeling) Islands
# CCK
# 18 Slovenia
# LJU
# 19 Guatemala
# GUA PBR FRS
# 20 Guinea
# CKY
# 21 Wallis And Futuna
# FUT WLS
# 22 Dominica
# DCF DOM
# 23 Australia
# WLP CPD BWT FIZ PKE BYP MJK ALH MNE PQQ CMA TSV EDR LST LSY WGA CBI CBR CTL CTN GLT AUU PUG MMM NTL NTN MMG SYD DPO HIS ONG KFE HID MKY OAG ONS ABM KTR ABX HGD KTA BHQ BHS CFS MIM KNS WTB PPP MRZ AYQ DBO OCM CED BME MGB WUN WYA ISA ASP DGE LNO RMA JCK CMD GTE GTS HVB PMK GYL KWM NRA GFN MCY MCV GFF LDH MQL HBA WEI BNK KNX BNE NIF PHE WIN PHQ EMD DMD BUY GET BUC TCA MHC MOV MOO BCI PER OLP KRB PLO CVQ MKR CVC ZNE LVO IRG ARM NAA EPR DRW TIS CCL TMW MYA BQB BQL WME FLS ROK CAZ MNG TRO BDB CJF PBO LRE AVV HTI GOV TEF BKQ CUQ DNM ELC ADL LEA MEB MEL XTO LER SGO CNS CNJ OOM OOL KGC KGI
# 24 Liberia
# ROB
# 25 Maldives
# IFU FVM KDO TMF KDM VAM DRV GAN GKK MLE HAQ
# 26 Pakistan
# GWD LHE RYK SKZ DEA ISB LYP KHI PZH UET MJD PEW CJL SKT DDU MUX KDU GIL TUK PJG BHV
# 27 Oman
# SLL KHS MCT
# 28 Tanzania
# DOD MUZ LKY ZNZ MFA SEU MBI TGT MYW PMA DAR MWZ BKZ SGX TKQ IRI JRO TBO ARK
# 29 Palestinian Territory
#
# 30 Saint Kitts And Nevis
# NEV SKB
# 31 Albania
# TIA
# 32 Gabon
# OYE LBV POG MVB
# 33 Saint Pierre and Miquelon
# FSP MQC
# 34 Monaco
# MCM
# 35 New Zealand
# TIU ZQN WRE PCN AKL WSZ WLG NSN KBZ OHA WHK HKK PPQ ROT CHC GIS WAG TUO DUD CHT TRG NPL HLZ IVC NPE BHE PMR KAT KKE
# 36 Yemen
# SAH RIY TAI ADE GXF
# 37 Jamaica
# OCJ MBJ KIN
# 38 Greenland
# AGM KUS QGQ UMD JHS NAQ JFR CNP JQA JSU UAK JUV GOH JAV THU JEG OBY SFJ
# 39 Samoa
# APW
# 40 United Arab Emirates
# RKT AAN DWC AUH SHJ DXB
# 41 Guam
# GUM
# 42 Kosovo
# PRN
# 43 India
# PAT NAG CCU TIR BOM AGX RAJ SXR VNS IXJ IXI IXL IXM IXB IXC IXA IXG IXD IXE IXZ JAI IXR IXS KNU IXU HJR MAA HBX JDH CCJ DEL DMU DED BUP TCR AMD CJB JGA VGA BLR TRZ BDQ SHL TRV JLR LKO GWL KUU IDR ATQ COK BKB TEZ UDR RDP BBI IMF VTZ JRH RUP HYD DIB DIU RPR GAY GAU PGH DHM GOI STV AJL GOP BHJ BHO PNQ RJA BHU
# 44 Azerbaijan
# KVD GYD NAJ LLK
# 45 Madagascar
# DIE TMM SMS TNR MJN SVB TLE FTU MOQ NOS
# 46 Lesotho
# MSU
# 47 Saint Vincent and the Grenadines
# SVD UNI
# 48 Kenya
# NYK ILU LOY UKA ASV UAS MBA NBO LOK WJR MYD KTL MRE KIS WIL EDL KEY LAU
# 49 South Korea
# KUV MWX USN YNY KWJ TAE KPO HIN CJJ ICN GMP CJU SHO WJU SYS RSU PUS
# 50 Tajikistan
# DYU TJU LBD KQT
# 51 Turkey
# SZF KSY MSR ERZ IST NAV DIY USQ ERC BAL CKZ ASR KFS TZX KYA MQM ISE VAS TEQ SXZ SAW KZR GNY VAN OGU DLM ADF AJI IGD ADB ESB ADA AYT MLX DNZ YEI ONQ KCM NOP KCO EDO EZS BJV NKT GZP GZT MZH TJK HTY
# 52 Afghanistan
# CCN TII BIN KDH KBL BST FAH HEA ZAJ MZR FBD
# 53 Fiji
# NAN SUV LBS RTA TVU KDV BFJ SVU KXF
# 54 Northern Mariana Islands
# ROP SPN
# 55 Andorra
#
# 56 Eritrea
# ASM
# 57 Solomon Islands
# MUA EGM IRA HIR SCZ BNY VAO FRE RBV CHY GZO RNL KGE RUS
# 58 Saint Lucia
# SLU UVF
# 59 Mongolia
# COQ ULZ ULN LTI ULG HVD AVK
# 60 France
# LIG LIL AGF EGC CCF BOD FNI SXB DCM LYS TLN UIP PIS LPY MRS LAI BVA SNR BVE CMF BES LDE DLE CSF LRH MPL LRT RNS FSC BZR DOL ETZ BSL TLS LTQ RDZ AUR CLY DNR CDG ORY PUF NTE TUF DIJ GNB PGF XCR BIA PGX BIQ MLH AJA CFR CFE EBU NCE
# 61 Bermuda
# BDA
# 62 Slovakia
# TAT PZY BTS KSC
# 63 Somalia
# GLK BIB KMU MGQ BSA HGA
# 64 Laos
# NEU ODY PKZ ZVK XKH VTE LPQ LXG
# 65 Nauru
# INU
# 66 Norway
# KSU LKN AES FDE SVG VAW EVE RET BGO BOO SKN OSY HOV LYR RVK VRY SOJ MQN OSL LKL KRS RRS MJF SVJ HAA SSJ FRO HFT BDU SRP BNN TRF HAU TOS BJF VDS SOG TRD ALF MEH HVG KKN BVG MOL SDN NTB ANX
# 67 Malawi
# CMK BLZ ZZU LLW CEH DWA LIX
# 68 Cook Islands
# AIU AIT RAR
# 69 Benin
# COO
# 70 Libya
# BEN TIP MJI TOB LAQ MRA
# 71 Cuba
# BCA CMW CCC GER CYO NBW GAO VRA SCU HOG BYM VTU MOA HAV CFG SNU MZO
# 72 Montenegro
# TIV TGD
# 73 Djibouti
# JIB
# 74 Togo
# LFW
# 75 China
# CKG ZQZ KRL JIQ NAO MIG ZYI WDS XIY DIG NAY AOG NNG HSN LYG LYA KHN DCY TAO LYI KHG HZG HAK JIC CHG WEH HZH LHW WNZ DQA LPF HRB WUS TYN WUZ WUX XMN SYM WUA JNG LXA JNZ ZAT SYX HJJ TSN SHP NGB YBP HDG FUG YIH JDZ FUO ZUH TCZ YZY WNH JMU SZX HMI JUZ LLB LLF HUZ DLC JGN YTY ENH YKH JGD LJG DSN SHA CSX DLU FOC ENY JGS DDG LZY CZX WUH KCA CGO HTN LCX LZH ZHY TCG LZO HLH HLD AVA SHE KMG CTU SHF AKU MDG DOY PEK HNY ACX HFE LUM XNN YNJ TEN XFN NBS HPG XUZ CGD TVS PVG CGQ HET TLQ KRY NNY YIC JZH YIN DNH NDG BSD YIW UYN MXZ GMQ HEK ZHA RLK JJN IQN NTG BAV YIE CIF JHG SWA CIH BPL HYN IQM AAT CAN YNZ YNT BPX KOW WEF TXN KWE FYJ URC FYN KWL XIC DAT HIA AQG GYS DYG DAX TGO YCU HXD XIL SJW JXA TNA HGH WXN NZH GOQ TNH KGT NKG BHY INC
# 76 Armenia
# LWN EVN
# 77 Dominican Republic
# JBQ PUJ LRM POP STI AZS SDQ
# 78 Germany
# DRS AGB BGN PAD SXF LBC HAJ HAM RLG DTM FDH HDF KSF SCN MHG XFW RBM GWT MUC RMS CGN NUE FRA FMO DUS NRN LEJ BRE ERF TXL FKB STR FMM HHN
# 79 Ukraine
# SIP VIN LWO IFO ODS KBP KHE KRQ DNK IEV HRK CWC OZH
# 80 Bahrain
# BAH
# 81 Tonga
# VAV TBU EUA
# 82 Cayman Islands
# CYB GCM LYB
# 83 Western Sahara
# EUN VIL
# 84 Finland
# JYV TMP KOK KUO VAA OUL RVN TKU JOE SVL KTT HEL MHQ KEM IVL KAJ KAO
# 85 Central African Republic
# BGF
# 86 Mauritius
# RRG MRU
# 87 Sweden
# LPI AGH HFS UME KSD NYO VBY BMA GEV HMV LYC LLA JKG OSD VXO TYF AJR HAD THN KRN KLR BLE GOT EVG KRF NRK VHM KVB MMX MXX OER SFT PJA RNB SDL ORB VST ARN
# 88 Vietnam
# DIN CAH VDH DAD PQC UIH HUI PXU BMV SGN VCA HAN DLI VCL HPH VCS VKG CXR TBB
# 89 Antigua And Barbuda
# ANU
# 90 Mali
# BKO
# 91 Russia
# URS CKH NAL EGO NYM NYA NNM OHH IWA MQF KHV VVO KYZ THX SVO OVS MRV IAA URJ LPK BQS SVX ZIA MJZ TYD KVK OVB PYJ REN KVX GRV AER DME KSZ KUF RGK CEE NER CEK OSW PKC RTW SCW HMA ROV IKS IGT KPW VKT YKS CSY HTG KXK HTA KCK NOZ INA BTK NOJ PEX PEZ PES PEE NJC NUX IKT ASF NBC KJA KRR VOZ VOG KRO LED KEJ GDX UFA GDZ UUS OMS MMK UUD KZN UKX TJM USK BAX AAQ TBW TOF SWT NSK CYX DYR UCT SGC EYK ABA KLF ULY SLY GOJ ULV STW VKO ESL KGP OGZ KGD MCX ARH IJK
# 92 Bulgaria
# SOF PDV VAR BOJ
# 93 United States
# AGN AGC AGS PKB SPZ SPS SPI BWG BWI BYI JNU SNA PQI SNK SNS SNP MAF YUM SNY BEH EVM BED BET LSE VLD TTN GRR GRB OXR GRK GRI HLN KKH ENW CTH EDC EDE LMT ORL ORH ORD DPA RCA ONP ONT CFK PNE SAN PRC SAC SAF SAD PVC CHA MRY JAX CHO CHS MRK JAE JAC MRB MRC APN DBQ APC APA APF ISN TKF HMT TKJ GCC DLG GCK DLH AFW BTT BTV BTP BTR SSI BTM BTL BTI LNY LNS LNN LNK PDT EUG BBD BBC YAK BBW TUP TUS TUL CYS EVV FYU FKL VCT CWA CKB PAE PAH DCA AWM MQT MQY FWA OME AET BUR BUF BLV PSK PSM MOR PSF PSG MOU MOT MOB PSP JLN MOD KMO HNM HNL BCB HNS BCT UIN PIZ TVL TVF TVC JZI SRQ TDZ NME LOL CVO LOU CVG WJF HLG ELM HPN HPB KKA WDG DRT DRO DRG RVS CXL CXO DHN SCM MNZ PTK SCK PTH SCE JMS SCC SCB PTW PTU MLI PBG PBI AVW AVP SUA SUN SUS SUX LFT TEB TEX NBG ADS ADQ DET DNV GMU MWC BRY BRW BRO BRL BRD TWF MWH EAA RKD EAR EAU EAT ESW KLG HOB HOM ESD VSF GOL SCF CVN VAK VAD PTV CMI CMH CMX ORF DSM DSI OKS INT RWI INS INL OKC BNA IND GLH AKP AKK AKN DOV GLV AUG AUS AUZ SBP MMU MMT SBY PUB MML MMH PUW SBN SBM ERV UKI KOA KOY ERI AVL VPS STC STL STK STP STS JXN NCN FNT LIH LIT FNL PGV WTK TPA HRL HRO KAE KAL RHI RME UGN RTN OJC ENA ENV RFD OXD OXC ATL ISP ATK ATW ISO ATS ISM ATY PVU PVD SEA SEM CLL CLM FRG FRD CLD CLE PDK IMT CLT FRY CLP PNS SWO SWF BPT GYR DNL MLB MLS MLU MLY NRB RIV RIW HSI HSL ADK RIL HSV RIF RIE RIC KNK HAO KNW HAR LXV JRA VQQ SYR EMK LDM LJN FOX YKM FOD FOE VGT TCL FOK WWT WWD SAA COS COU ILN FSM ILI WAA SAV SAT RUT MKG MKE MKC DIK MKO MKL JHM JHW AID AIA UTM IRK JAN RKS SDX SDY SDF PWA PWM PWK MRI BOS BOI SXY LYH ILM BQK PEQ RKH COD FLL FLO FLG HON ALS TRI TRM TRX HTO HTH HOU HTS ESC RDU HSP ELD RDD RDG ELY RDB RDM ELP LEB LEE LEX USA AZO AZA UST SGY SGR SGU SGF CNY CNM ICT SIT SIY SIK TAL GIF AHN NPT GUC GUP HUL HCR BLI BLH KPN LZU EKO EKA OUN LFK FCA FCM FMY MKK FMN VEE YIP VEL AIN AIK CAK CAE PGD PGA PDX OGS UDD RST OGG RSW JFK MIA AOO NQX SDP SOW IPL SFO IPT SFB NGU KSM HDN BMG BMI SHR SHV SHX SHD SHH MGE MGM MGW LAR TBN LUR VJI LUK GTF ECP VTN GTR TLH GCN HVR ILG UCA RBY RBL RBD OTH OTM LGB LGA TLA LGD OTZ AXS AXV AXN IWD IAN IAH IAG PHO PHN PHL HVN PHF PHX SKF SKK MFE MFR GEG MHK GKT DDC MHT MHR ANC ANI GWO TMB IGM NJK HWD HES BJC BJJ BJI HYA HYG WSN FAY FAR OWD OWA FAT OWB FAI LVS VKS SVA LVK OAK OAJ CCR PIH PIA PIB MYR MYU PIE MYV MYL PIP PIR PIT CYF ZPH WMO WMC KVL GJT MWA DEN DEC AMA GGW GNV VCV ACK NEA XNA KUK ACV ACT NEW ACY HFD BKG BKC BKL BKW VDZ SJT SJC GDV MEM MEO MEI PSC LWS YNG LWT LWB LWC TXK SMF TNP TNC GVT HHR JEF HHH WLK CPR CPS WRG WRB WRI LAL LAN LAF FFT LAA FFM LAX LAW LAS DTN PUC DTW SBA BDL FTW CBE SMX SMO SMN BZN MDH JST GGG MDW MDT MVW MVY DFW MVL ALO ALM ALB ALW TOP TOI TOL TOC TOA TOG KFP NHK KOT HIB HIF IAD ABE ABI ABL KTS ABQ ABR ABY BHM BHB EGE LBB LBE RAP LBF LBL BFF BFD BFI BFM BFL NUI EYW VIS TYQ TYR TYS IFP OCF CEC CEM CEU PKA CEZ HGR CSG CSV KTN FSD MUT JBR MUE MUO AST NUQ ASE AEX ASN ASL DUJ UNU DMA DUA UNK DUT ITO OMA ITH ELI BIL BIF KWN KWT BIS SLN SLJ SLK SLE SLC MCO MCN MCK MCI MCG MCE GFK GFL MCW FHU BGM BGR LQK VNC VNY GPZ GPT CRP CRW FDK CRG WNA EFD RNO LCQ OPF LCK LCH DVL DVT OLF IKB OLS CDB CDC CDV CDR PLN MBL PPA GAM GAL GAI SOV MBS MTJ MTH MTN JCI ART ARG GSP GST TIW GSH GSO HKS GKY HNH KVC BVU BVY BVO ROA ROC OSU ROG OSC ROW EWN EWB BDR EWR LRD IDA CGI VRB CGF CUB CIC MSY CID CIK MSS MSP MSO MSN MSL CIU DAG DAB DAL DAN DAY DWH OOK
# 94 Romania
# BCM SCV SUJ CLJ ARW SBZ OMR CND CRA OTP TSR IAS
# 95 Angola
# SZA MSZ CAB VHC LUO SPP VPE SVP SDD CBT LAD NOV
# 96 Chad
# NDJ
# 97 South Africa
# SIS CPT MQP PRY PZB BFN JNB KIM PHW HDS NGL SZK PTG LDZ PBZ GRJ MGH HLA PZL ELS DUR NTY PLZ KOF RCB MBD ULX UTN UTT
# 98 Cyprus
# ECN PFO LCA
# 99 Caribbean Netherlands
# SAB EUX BON
# 100 Malaysia
# JHB LKH BBN MKM TWU KUL KUD LWY KUA MYY LBU SZB BKM BKI MKZ MUR AOR LDU KBR TGG ODN KTE BLG BTU LGK MZV SBW LGL IPH KCH LMN PEN SDK
# 101 Austria
# LNZ VIE GRZ SZG KLU INN
# 102 Mozambique
# MPM VPY BEW POL TET MNC VNX APL UEL VXC INH
# 103 Uganda
# EBB RUA PAF
# 104 Japan
# AXT AXJ HSG IWO IWK IWJ MYJ HKD HAC KIX OIM SYO KIJ OIR UBJ TSJ NGO NGS FUJ FUK TKN TTJ TKS TRA UEO SHB SHM RNJ OIT KKX TJH OKA OKE OKD KKJ OKI OKJ KCZ HNA HND CTS KMJ KMI AOJ AKJ KUM TOY KMQ KUH FSZ ISG ASJ IKI OBO ITM MMY NTQ MMJ MMD TAK MMB KOJ YGJ MSJ IBR UKB ONJ MBE GAJ HIJ IZO TNE KTD FKS WKJ NKM OGN SDJ NRT
# 105 Niger
# NIM
# 106 Brazil
# MII OAL URG CPV PAV RVD BVH IOS PET JOI RIA OPS XAP GIG BYO LAJ IPN BVB MAB THE UBA CXJ JDO CKS BEL CMG VDC FLN LDB ROO SDU PNZ TJL AFL IGU GRU RBR SLZ DIQ VIX VCP NVT MGF CZS MAO TBT RAO SSA UDI NAT ATM REC DOU CGH PMW TXF CGB JTC PVH CGR BSB FEN CAW PFB AUX CLV TFF PLU LEC BRA BPG BPS CAC AAX FOR PPB GYN SJP POA IZA STM AJU CNF MOC GVR CWB ARU IMP JPA VAG CFB MCZ JPR MCP
# 107 Faroe Islands
# FAE
# 108 Kuwait
# KWI
# 109 Panama
# CTD PAC BOC DAV PTY RIH CHX BLB PUE
# 110 Guyana
# OGL GEO
# 111 Costa Rica
# TMU LIO GLF LIR XQP TNO TTQ PMZ FON PJM NOB SYQ SJO
# 112 Luxembourg
# LUX
# 113 American Samoa
# PPG
# 114 Bahamas
# AXP RCY CCZ NAS SML ZSA GHB NET GGT BIM TCB TZN ELH RSD MHH FPO IGA CAT SAQ TYM LGI TBI
# 115 British Virgin Islands
# NGD EIS VIJ
# 116 Gibraltar
# GIB
# 117 Ireland
# CFN NOC SNN KIR DUB ORK
# 118 Italy
# SUF FLR CIA TSF VBS NAP CTA BGY CIY PEG CAG REG OLB TAR TRN AOI PMF GOA VCE PMO LIN PNL BLQ CUF TPS BDS TRS RMI EBA LMP PSA AHO MXP VRN BRI PSR FCO
# 119 Nigeria
# AKR LOS ILR SKO MIU QOW IBA QRW ABB YOL BNI JOS ENU ABV KAD PHC KAN CBQ QUO
# 120 Ecuador
# LOH GYE UIO SCY GPS OCC CUE ESM SNC MEC LGQ
# 121 Bangladesh
# DAC SPD CXB JSR CGP BZL ZYL RJH
# 122 Brunei
# BWN
# 123 Belarus
# MSQ
# 124 Iran
# OMH AEU AZD MRX GBT XBJ HDM GSM IFN DEF BUZ AWZ LFM KSH IKA PGU ZBR TBZ IIL KHD RAS ADU ABD MHD BDH SYZ AJK RZR AFZ SRY BND YEH BJB ZAH NSH THR SDG KIH LRR KER
# 125 Algeria
# AAE TMR TMX GJL GHA TID AZR TGR VVZ TEE BMW BSK HME IAM ELG LOO DJG BLJ TLM ELU MZW INZ BJA ALG CBH OGX TIN ORN CZL QSF
# 126 El Salvador
# SAL
# 127 Tuvalu
# FUN
# 128 Gambia
# BJL
# 129 Czech Republic
# PRG OSR BRQ KLV
# 130 Marshall Islands
# KWA MAJ
# 131 Chile
# CPO IQQ CCP SCL LSC WPU WPR CJC ZAL BBA ZOS IPC ANF ZCO PMC ARI PUQ
# 132 Puerto Rico
# CPX MAZ BQN VQS PSE SIG SJU
# 133 Belgium
# KNO KJK BRU LGG ANR OST CRL
# 134 Kiribati
# CXI TRW
# 135 Haiti
# PAP CAP
# 136 Belize
# SPR BZE
# 137 Hong Kong
# HKG
# 138 Sierra Leone
# FNA KBS
# 139 Georgia
# BUS TBS KUT
# 140 Denmark
# CPH AAL AAR SGD KRP BLL RNN EBJ
# 141 Philippines
# SUG TAG DVO VRC BCD PAG BXU USU TWT CRK DPL CRM GES PPS CYP CGM CEB CYU CYZ CGY WNP BSO MNL DGT ILO MBT TDG ZAM KLO RXS OMC LAO OZC CBO MPH TBH SJI TAC LGP TUG
# 142 Moldova
# KIV
# 143 French Guiana
# CAY
# 144 Morocco
# CMN GLN AGA ERH RAK TTU OUD TTA ESU AHU TNG NDR FEZ RBA OZG OZZ
# 145 Namibia
# ERS WDH LUD OND WVB NDU MPA KAS OMD
# 146 French Polynesia
# AXR FAV TIH MKP MVT BOB HUH UAH NHV TKP PPT TKX RFP XMH HOI AUQ RGI GMR MOZ MAU AHE APK UAP RUR TUB
# 147 Guinea-Bissau
# OXB
# 148 Thailand
# LOE NAK USM DMK HDY NAW KOP TST ROI PRH CEI BKK KDT NNT NST CJM UTH LPT THS CNX HGN UTP BFV HKT UNN MAQ URT HHQ UBP KBV TDX SNO PHS KKC
# 149 Switzerland
# ACH GVA BRN LUG ZRH
# 150 Grenada
# GND
# 151 Cote D'ivoire (Ivory Coast)
# BGG SPY ABJ OFI HGO BYK
# 152 U.S. Virgin Islands
# STT STX
# 153 Seychelles
# PRI SEZ
# 154 Portugal
# BGC CVU FLW FNC LIS SMA PRM PIX PXO FAO TER VRL SJZ GRW PDL VSE HOR OPO
# 155 Estonia
# KDL URE TAY TLL
# 156 Uruguay
# MDO MVD RCH PDP
# 157 Equatorial Guinea
# SSG BSG
# 158 Lebanon
# BEY
# 159 Uzbekistan
# FEG BHK KSQ AZN TAS UGC NCU SKD NMA TMJ NVI
# 160 Egypt
# HBE CAI ASW ATZ RMF HMB ABS HRG LXR SSH
# 161 Falkland Islands (Malvinas)
# MPN
# 162 Rwanda
# KME KGL GYI
# 163 Timor-Leste
# DIL
# 164 Spain
# VLL BCN ACE ILD REU IBZ FUE VDE TFS AGP BIO VGO VLC VIT SPC SCQ PMI MAD OZP MLN GRX GMZ MJV XRY GRO EAS LPA SVQ TFN SDR LEI ALC LEN CDT LCG ZAZ OVD PNA MAH RJL BJZ
# 165 Colombia
# BGA EOH AXM UIB RVE NQU PDA GPI EYP LQM IPI APO MZL PEI VUP PCR CRC FLA TCO BUN PTX BOG VGZ PSO CZU NVA SMR CTG TME MDE BSC MVP AUC CLO TLU ADZ CUC SJE VVC LET PUU BAQ IBE SQB PPN MTR EJA
# 166 Reunion
# ZSE RUN
# 167 Burundi
# BJM
# 168 Taiwan
# SMT TSA RMQ HUN MFK TTT KHH CYI TPE KNH TNN MZG LZN
# 169 Turks and Caicos Islands
# GDT PLS XSC
# 170 Barbados
# BGI
# 171 Qatar
# DOH
# 172 Palau
# ROR
# 173 Curacao
# CUR
# 174 Bhutan
# PBH
# 175 Sudan
# KST PZU EGN ELF DOG KRT UYL EBD MWE KSL RSS
# 176 Nepal
# LUA SIF TMI PKR JKR BWA JMO BIR DHI KTM BDP BHR KEP
# 177 São Tomé and Principe
# PCP TMS
# 178 Micronesia
# PNI KSA TKK YAP
# 179 Netherlands
# GRQ MST RTM AMS EIN
# 180 Bosnia And Herzegovina
# SJJ BNX OMO TZL
# 181 Suriname
# PBM
# 182 Anguilla
# AXA
# 183 Venezuela
# CCS MUN VLN SOM PZO LSP LFR STD BNS PMV CUM BLA MAR VIG PYH BRM LRV CZE
# 184 Israel
# TLV SDV VDA HFA ETH
# 185 Indonesia
# RTI NAH SOQ LSW BWX LUW TRK LBJ PLW WMX SRG NTX KNG DJB DJJ TIM TMC KAZ SQG BEJ FLZ JOG AEG UOL TKG RTG PKU PKY BUW TTE BMU AMQ MNA PKN KBU ENE UPG BDO BDJ NBX WGP PSJ BTW HLP TJQ TJS OKL BTH ABU SXK SUB LUV DOB SMQ GLX CGK KTG KDI MDC BKS DUM OTI SRI TLI LKA PSU BJW MEQ SBG PLM GNS DPS MWK KOE BPN MKW LOP SWQ BXB SOC BIK PGK PDG MLG FKQ GTO TNJ MKQ NRE MOF PNK ARD BTJ
# 186 Iceland
# AEY GJR HFN IFJ RKV EGS SUY BIU VPN HZK GRY THO VEY KEF
# 187 Zambia
# KAA KLB LVI MNR NLA MFU SLI ZKP LUN
# 188 Senegal
# DKR CSK KDA ZIG
# 189 Papua New Guinea
# VAI LAE MAG GUR MXH MDU HGU PNP RAB MAS TBG LNV POM UNG BUL BUA GKA WWK HKN WBM TIZ DAU
# 190 Zimbabwe
# BUQ VFA HRE
# 191 Jordan
# AMM AQJ
# 192 Vanuatu
# LOD CCV TOH VLI NUS SON LNE TGH TAH LNB MTV ZGU FTA SLH DLY WLH SSR
# 193 Martinique
# FDF
# 194 Kazakhstan
# DMB AKX TSE DZN GUW CIT ALA KOV SCO KSN PPK URA PWQ PLX KGF UKK KZO
# 195 Poland
# SZZ RZE POZ LUZ KTW BZG KRK WMI SZY IEG WRO WAW RDO LCJ GDN
# 196 Mauritania
# OUZ NDB NKC
# 197 Kyrgyzstan
# OSS FRU
# 198 Mayotte
# DZA
# 199 Iraq
# ISU NJF EBL BSR SDA BGW
# 200 Montserrat
# MNI
# 201 New Caledonia
# MEE LIF KOC UVE GEA TOU ILP NOU TGJ KNQ
# 202 Macedonia
# OHD SKP
# 203 North Korea
# FNJ
# 204 Paraguay
# ASU AGT
# 205 Latvia
# RIX
# 206 South Sudan
# JUB
# 207 Hungary
# BUD DEB
# 208 Syria
# KAC DAM
# 209 Guadeloupe
# PTP
# 210 Burma
# AKY MNU KMV LIW BPE RGN TVY MDL BMO LSH KHM KYP PBU THL NYU HEH HOX SNW KAW MGU MGZ KET MYT
# 211 Honduras
# RTB UII PEU SAP XPL TGU LCE
# 212 Malta
# MLA
# 213 Mexico
# PAZ CPE TIJ AGU OAX CUL TAP TAM MID TPQ ZIH MZT MAM GUB CME CEN HMO NLD HUX UPN TRC BLM PBC CJS LAP MXL LZC ACA CTM PVR DGO ZLO CUU VER PDS CZM TLC CUA CUN LTO CLQ SJD LMM GDL MEX BJX CVM CVJ TGZ GYM QRO PXM MTY REX SLW SLP MTT MLM ZCL VSA
# 214 Tunisia
# TOE DJE TUN MIR NBE SFA
# 215 Nicaragua
# BZA SIU NCR BEF MGA WSP PUZ
# 216 Singapore
# SIN
# 217 Serbia
# INI BEG KID
# 218 Comoros
# HAH AJN NWA
# 219 United Kingdom
# BOH EXT PIK NQY LYX LBA GLA SOU WRY BFS SOY LPL LHR GXH NWI SYY MAN EMA BEB LKZ CEG BUT LSI VLY LDY HUY TRE OXF DSA CBG INV LCY KOI ISC COL ILY SEN DND NDY LTN WIC EDI BRS BRR LEQ MME OBN CVT CAL PPW STN CWL ABZ NRL BHD BHX NCL LGW
# 220 Trinidad And Tobago
# POS TAB
# 221 Antarctica
#
# 222 Congo
# KND BZV KMK BUX BKY FKI MDK MJM GMA FMI FIH GOM PNR KGA FBM KGN
# 223 Greece
# SKU PAS SMI JSH ATH SKG AXD KSO KSJ AOK JSI JKL JMK JKH PVK JSY IOA JTY ZTH HER JIK MLO MJT CHQ EFL JTR KLX KZS KGS KZI LXS KVA JNX GPA KIT LRS RHO CFU
# 224 Sri Lanka
# CMB GIU HRI
# 225 Croatia
# ZAD SPU OSI PUY ZAG BWK RJK DBV
# 226 Botswana
# GBE BBK MUB FRW

# %%
file("../json/cluster.json",'w').write(json.dumps(SD))
